# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
HR=pd.read_csv("Homelessness Report .csv")
print(HR)
# Out:
#        Region Total Adults Male Adults Female Adults  Adults Aged 18-24  \
# 0      Dublin        4,287       2,776         1,511                708
# 1    Mid-East          318         205           113                 51
# 2    Midlands           91          60            31                 21
# 3    Mid-West          299         203            96                 31
# 4  North-East           75          59            16                  5
# 5  North-West           74          51            23                 14
# 6  South-East          193         137            56                 29
# 7  South-West          512         361           151                 65
# 8        West          282         166           116                 65
#
#   Adults Aged 25-44 Adults Aged 45-64  Adults Aged 65+  \
# 0             2,374             1,141               64
# 1               162                96                9
# 2                49                18                3
# ...

# %%
HR["Adults Aged 18-24"].describe()
# Out:
# count      9.000000
# mean     109.888889
# std      225.305040
# min        5.000000
# 25%       21.000000
# 50%       31.000000
# 75%       65.000000
# max      708.000000
# Name: Adults Aged 18-24, dtype: float64

# %%
Hag=pd.read_csv("Housing Adaption Grant .csv")
print(Hag)
# Out:
#                    Local Authority  Number of payments 2014  \
# 0            Carlow County Council                       73
# 1             Cavan County Council                       48
# 2             Clare County Council                       84
# 3              Cork County Council                      113
# 4           Donegal County Council                       11
# 5   Dun L.-Rathdown County Council                       18
# 6            Fingal County Council                       37
# 7            Galway County Council                       87
# 8             Kerry County Council                      118
# 9           Kildare County Council                       12
# 10         Kilkenny County Council                       52
# 11            Laois County Council                       63
# 12          Leitrim County Council                       17
# 13        Limerick City and County                      180
# 14         Longford County Council                       53
# ...

# %%
kn=pd.read_excel("knowledge.xlsx")
print(kn)
# Out:
#                  Education  Year  Knowledge of female circumcision  \
# 0  Primary or No education  2003                              41.1
# 1  Primary or No education  2008                              48.9
# 2  Primary or No education  2013                              64.9
# 3  Primary or No education  2018                              57.4
# 4      Secondary or higher  2003                              73.8
# 5      Secondary or higher  2008                              76.3
# 6      Secondary or higher  2013                              70.7
# 7      Secondary or higher  2018                              64.1
#
#    Prevalence of female circumcised  Unnamed: 4
# 0                              13.1         NaN
# 1                              24.3         NaN
# 2                              21.5         NaN
# 3                              19.5         NaN
# 4                              28.9         NaN
# 5                              36.2         NaN
# ...

# %%
vl=pd.read_csv("violence.csv")
print(vl)
# Out:
#              Location  Domestic Violence  Rape  Sexual Abuse  Defilement
# 0     Warri / Effurun                 50    10            32          30
# 1  Asaba and Environs                 40    15            28          20
# 2             Ughelli                 20     5             8          31
# 3                Oleh                 10     0             0           7

# %%
rp=pd.read_csv("rape-incidence.csv")
print(rp)
# Out:
#     Year            Place of Rape     Age Group     F    M  Total     %F
# 0   2015                     Home  17 and under   485   54    539  89.98
# 1   2015                     Home         18-27   262  178    440  59.55
# 2   2015                     Home    28 & above    60  156    216  27.78
# 3   2015                     Home   Sub - Total   807  388   1195  67.53
# 4   2015                   School  17 and under    61   14     75  81.33
# 5   2015                   School         18-27   238  214    452  52.65
# 6   2015                   School    28 & above     3   31     34   8.82
# 7   2015                   School   Sub - Total   302  259    561  53.83
# 8   2015                   Others  17 and under   109   38    147  74.15
# 9   2015                   Others         18-27    56   70    126  44.44
# 10  2015                   Others    28 & above    77   37    114  67.54
# 11  2015                   Others   Sub - Total   242  145    387  62.53
# ...

# %%
pr=pd.read_csv("wanadata-worksheet-sexual-offences-pg-49-pdf.csv")
print(pr)
# Out:
#      Year  Type of Offence        M        F    F%
# 0    2013              Debt     618       28  4.33
# 1    2013             Arson     685       14     2
# 2    2013            Affray    1000       12  1.19
# 3    2013           Assault    8301      681  7.58
# 4    2013            Murder    6852      320  4.46
# ..    ...               ...     ...      ...   ...
# 119  2016    Cultism/Ritual     401        2   0.5
# 120  2016   Breach of peace     948       26  2.67
# 121  2016     Other Offence   25942     1442  5.27
# 122  2016             Total   36481     6367  4.46
# 123  2016  Total calculated  136384  6365.83   NaN
#
# [124 rows x 5 columns]
