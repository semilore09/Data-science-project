# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bn=pd.read_csv("Billionaire.csv")
print(bn)
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# ...

# %%
US=bn[bn["Country"]=="United States"]
print(US)
# Out:
#                        Name NetWorth        Country              Source  Rank  \
# 0                Jeff Bezos   $177 B  United States              Amazon     1
# 1                 Elon Musk   $151 B  United States       Tesla, SpaceX     2
# 3                Bill Gates   $124 B  United States           Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States            Facebook     5
# 5            Warren Buffett    $96 B  United States  Berkshire Hathaway     6
# ...                     ...      ...            ...                 ...   ...
# 2732             Vlad Tenev     $1 B  United States       stock trading  2674
# 2739  Vlad Vendrow & family     $1 B  United States            software  2674
# 2742        J. Wayne Weaver     $1 B  United States               Shoes  2674
# 2743            Sandy Weill     $1 B  United States           Citigroup  2674
# 2749             Yu De-Chao     $1 B  United States     pharmaceuticals  2674
#
# ...

# %%
US[US["Age"]<=50]
# Out:
#                      Name NetWorth        Country                 Source  \
# 1               Elon Musk   $151 B  United States          Tesla, SpaceX
# 4         Mark Zuckerberg    $97 B  United States               Facebook
# 7              Larry Page  $91.5 B  United States                 Google
# 8             Sergey Brin    $89 B  United States                 Google
# 21        MacKenzie Scott    $53 B  United States                 Amazon
# ...                   ...      ...            ...                    ...
# 2675          Baiju Bhatt     $1 B  United States      stock trading app
# 2681              GT Dave     $1 B  United States               kombucha
# 2700  Kim Kardashian West     $1 B  United States  cosmetics, reality TV
# 2702              Bom Kim     $1 B  United States       online retailing
# 2732           Vlad Tenev     $1 B  United States          stock trading
#
#       Rank   Age               Industry
# 1        2  49.0             Automotive
# ...
