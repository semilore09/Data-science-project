# %% [markdown]
# ###

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
rp=pd.read_csv("rape-incidence.csv")
print(rp)
# Out:
#     Year            Place of Rape     Age Group     F    M  Total     %F
# 0   2015                     Home  17 and under   485   54    539  89.98
# 1   2015                     Home         18-27   262  178    440  59.55
# 2   2015                     Home    28 & above    60  156    216  27.78
# 3   2015                     Home   Sub - Total   807  388   1195  67.53
# 4   2015                   School  17 and under    61   14     75  81.33
# 5   2015                   School         18-27   238  214    452  52.65
# 6   2015                   School    28 & above     3   31     34   8.82
# 7   2015                   School   Sub - Total   302  259    561  53.83
# 8   2015                   Others  17 and under   109   38    147  74.15
# 9   2015                   Others         18-27    56   70    126  44.44
# 10  2015                   Others    28 & above    77   37    114  67.54
# 11  2015                   Others   Sub - Total   242  145    387  62.53
# ...

# %%
rp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           39 non-null     int64
#  1   Place of Rape  39 non-null     object
#  2   Age Group      39 non-null     object
#  3   F              39 non-null     int64
#  4   M              39 non-null     int64
#  5   Total          39 non-null     int64
#  6   %F             39 non-null     float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 2.3+ KB

# %%
m=rp.M/rp.Total*100
print(m)
# Out:
# 0     10.018553
# 1     40.454545
# 2     72.222222
# 3     32.468619
# 4     18.666667
# 5     47.345133
# 6     91.176471
# 7     46.167558
# 8     25.850340
# 9     55.555556
# 10    32.456140
# 11    37.467700
# 12    36.957536
# 13     9.436834
# 14    23.474178
# 15    55.555556
# 16    23.274596
# 17    31.343284
# 18    82.278481
# 19    70.967742
# 20    43.146067
# 21    25.165563
# 22    17.600000
# 23    40.306122
# 24    26.968174
# 25    27.870216
# 26    15.708812
# 27    22.314050
# 28    62.179487
# 29    30.669145
# 30     1.183432
# 31    44.444444
# 32    33.333333
# 33     6.632653
# 34    24.050633
# 35    75.806452
# 36    27.586207
# 37    45.454545
# 38    30.674264
# dtype: float64

# %%
a=np.round(m,2)
print(a)
# Out:
# 0     10.02
# 1     40.45
# 2     72.22
# 3     32.47
# 4     18.67
# 5     47.35
# 6     91.18
# 7     46.17
# 8     25.85
# 9     55.56
# 10    32.46
# 11    37.47
# 12    36.96
# 13     9.44
# 14    23.47
# 15    55.56
# 16    23.27
# 17    31.34
# 18    82.28
# 19    70.97
# 20    43.15
# 21    25.17
# 22    17.60
# 23    40.31
# 24    26.97
# 25    27.87
# 26    15.71
# 27    22.31
# 28    62.18
# 29    30.67
# 30     1.18
# 31    44.44
# 32    33.33
# 33     6.63
# 34    24.05
# 35    75.81
# 36    27.59
# 37    45.45
# 38    30.67
# dtype: float64

# %%
rp["%M"]=a
print(rp)
rp.to_json("C:/Users/User/Desktop/newrape.json")
# Out:
#     Year            Place of Rape     Age Group     F    M  Total     %F  \
# 0   2015                     Home  17 and under   485   54    539  89.98
# 1   2015                     Home         18-27   262  178    440  59.55
# 2   2015                     Home    28 & above    60  156    216  27.78
# 3   2015                     Home   Sub - Total   807  388   1195  67.53
# 4   2015                   School  17 and under    61   14     75  81.33
# 5   2015                   School         18-27   238  214    452  52.65
# 6   2015                   School    28 & above     3   31     34   8.82
# 7   2015                   School   Sub - Total   302  259    561  53.83
# 8   2015                   Others  17 and under   109   38    147  74.15
# 9   2015                   Others         18-27    56   70    126  44.44
# 10  2015                   Others    28 & above    77   37    114  67.54
# 11  2015                   Others   Sub - Total   242  145    387  62.53
# ...

# %%
rp.describe()
# Out:
#              Year            F           M        Total         %F
# count    39.00000    39.000000   39.000000    39.000000  39.000000
# mean   2016.00000   293.461538  137.307692   430.769231  62.967949
# std       0.82717   378.468718  169.713094   534.906655  21.092096
# min    2015.00000     3.000000    2.000000     9.000000   8.820000
# 25%    2015.00000    60.500000   34.500000   122.500000  54.190000
# 50%    2016.00000   174.000000   79.000000   250.000000  67.540000
# 75%    2017.00000   314.000000  163.000000   495.000000  76.240000
# max    2017.00000  1734.000000  792.000000  2404.000000  98.820000

# %%
#creating a stacked bar chart
b=["HOME","SCHOOL","OTHERS "]
n=3
ind=np.arange(n)
width=0.25
r=rp["F"].iloc[0]
s=rp["F"].iloc[4]
t=rp["F"].iloc[8]
y1=np.array([r,s,t])
print(y1)
r=rp["F"].iloc[1]
s=rp["F"].iloc[5]
t=rp["F"].iloc[9]
y2=np.array([r,s,t])
print(y2)
r=rp["F"].iloc[2]
s=rp["F"].iloc[6]
t=rp["F"].iloc[10]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(121)
plt.bar(ind,y1,width,color="r",edgecolor="black")
plt.bar(ind+width,y2,width,color="g",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="b",edgecolor="black")
plt.xticks(ind+width,b)
plt.xlabel("Place of Rape")
plt.ylabel("Female Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group")
plt.title("No of Female Rape cases in 2015")

X=["HOME","SCHOOL","OTHERS"]
n=3
ind=np.arange(n)
width=0.25
r=rp["M"].iloc[0]
s=rp["M"].iloc[4]
t=rp["M"].iloc[8]
y1=np.array([r,s,t])
print(y1)
r=rp["M"].iloc[1]
s=rp["M"].iloc[5]
t=rp["M"].iloc[9]
y2=np.array([r,s,t])
print(y2)
r=rp["M"].iloc[2]
s=rp["M"].iloc[6]
t=rp["M"].iloc[10]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(122)
plt.bar(ind,y1,width,color="r",edgecolor="black")
plt.bar(ind+width,y2,width,color="g",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="b",edgecolor="black")
plt.xticks(ind+width,X)
plt.xlabel("Place of Rape")
plt.ylabel("male Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group")
plt.title("No of Male Rape cases in 2015")
plt.show()
# Out:
# [485  61 109]
# [262 238  56]
# [60  3 77]
# [54 14 38]
# [178 214  70]
# [156  31  37]

# %%
#creating a stacked bar chart
b=["HOME","SCHOOL","OTHERS"]
n=3
ind=np.arange(n)
width=0.25
r=rp["F"].iloc[13]
s=rp["F"].iloc[17]
t=rp["F"].iloc[21]
y1=np.array([r,s,t])
print(y1)
r=rp["F"].iloc[14]
s=rp["F"].iloc[18]
t=rp["F"].iloc[22]
y2=np.array([r,s,t])
print(y2)
r=rp["F"].iloc[15]
s=rp["F"].iloc[19]
t=rp["F"].iloc[23]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(121)
plt.bar(ind,y1,width,color="b",edgecolor="black")
plt.bar(ind+width,y2,width,color="g",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="y",edgecolor="black")
plt.xticks(ind+width,b)
plt.xlabel("Place of Rape")
plt.ylabel("Female Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group")
plt.title("No of Female Rape cases in 2016")

X=["HOME","SCHOOL","OTHERS"]
n=3
ind=np.arange(n)
width=0.25
r=rp["M"].iloc[13]
s=rp["M"].iloc[17]
t=rp["M"].iloc[21]
y1=np.array([r,s,t])
print(y1)
r=rp["M"].iloc[14]
s=rp["M"].iloc[18]
t=rp["M"].iloc[22]
y2=np.array([r,s,t])
print(y2)
r=rp["M"].iloc[15]
s=rp["M"].iloc[19]
t=rp["M"].iloc[23]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(121)
plt.bar(ind,y1,width,color="b",edgecolor="black")
plt.bar(ind+width,y2,width,color="g",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="y",edgecolor="black")
plt.xticks(ind+width,X)
plt.xlabel("Place of Rape")
plt.ylabel("male Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group",loc="upper right")
plt.title("No of Male Rape cases in 2016")
plt.show()
# Out:
# [595 230 113]
# [326  14 206]
# [124   9 117]
# [ 62 105  38]
# [100  65  44]
# [155  22  79]

# %%
#creating a stacked bar chart
b=["HOME","SCHOOL","OTHERS"]
n=3
ind=np.arange(n)
width=0.25
r=rp["F"].iloc[26]
s=rp["F"].iloc[30]
t=rp["F"].iloc[34]
y1=np.array([r,s,t])
print(y1)
r=rp["F"].iloc[27]
s=rp["F"].iloc[31]
t=rp["F"].iloc[35]
y2=np.array([r,s,t])
print(y2)
r=rp["F"].iloc[28]
s=rp["F"].iloc[32]
t=rp["F"].iloc[36]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(121)
plt.bar(ind,y1,width,color="b",edgecolor="black")
plt.bar(ind+width,y2,width,color="m",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="c",edgecolor="black")
plt.xticks(ind+width,b)
plt.xlabel("Place of Rape")
plt.ylabel("Female Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group")
plt.title("No of Female Rape cases in 2017")

X=["HOME","SCHOOL","OTHERS"]
n=3
ind=np.arange(n)
width=0.25
r=rp["M"].iloc[26]
s=rp["M"].iloc[30]
t=rp["M"].iloc[34]
y1=np.array([r,s,t])
print(y1)
r=rp["M"].iloc[27]
s=rp["M"].iloc[31]
t=rp["M"].iloc[35]
y2=np.array([r,s,t])
print(y2)
r=rp["M"].iloc[28]
s=rp["M"].iloc[32]
t=rp["M"].iloc[36]
y3=np.array([r,s,t])
print(y3)
plt.figure(figsize=[15,5])
plt.subplot(121)
plt.bar(ind,y1,width,color="b",edgecolor="black")
plt.bar(ind+width,y2,width,color="m",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="c",edgecolor="black")
plt.xticks(ind+width,X)
plt.xlabel("Place of Rape")
plt.ylabel("male Total")
plt.legend(["17 and under ","18-27","28 & above"],title="Age Group",loc="upper center")
plt.title("No of Male Rape cases in 2017")
plt.show()
# Out:
# [220 167  60]
# [94 10 30]
# [59  6 84]
# [41  2 19]
# [27  8 94]
# [97  3 32]

# %%
b=["2015","2016","2017"]
n=3
ind=np.arange(n)
width=0.25
r=rp["F"].iloc[12]
s=rp["F"].iloc[25]
t=rp["F"].iloc[38]
y1=np.array([r,s,t])
print(y1)
r=rp["M"].iloc[12]
s=rp["M"].iloc[25]
t=rp["M"].iloc[38]
y2=np.array([r,s,t])
print(y2)
r=rp["Total"].iloc[12]
s=rp["Total"].iloc[25]
t=rp["Total"].iloc[38]
print(y3)
y3=np.array([r,s,t])
plt.figure(figsize=[10,5])
plt.bar(ind,y1,width,color="c",edgecolor="black")
plt.bar(ind+width,y2,width,color="b",edgecolor="black")
plt.bar(ind+width*2,y3,width,color="y",edgecolor="black")
plt.xticks(ind+width,b)
plt.xlabel("Years")
plt.ylabel("Total National Rape Incidence")
plt.legend(["Female","Male","Total"])
plt.title("National Rape Incidence")
# Out:
# [1351 1734  730]
# [792 670 323]
# [2143 2404 1053]
# Text(0.5, 1.0, 'National Rape Incidence')

# %%
#piechart is used for categorical data
#explode slice out a pie
#autopct="%.1f%%" inserts percentahe 
a=rp["%F"].iloc[3]
b=rp["%F"].iloc[7]
c=rp["%F"].iloc[11]
d=a,b,c
print(d)
myexplode=[0.05,0,0]
plt.figure(figsize=(10,5))
plt.subplot(121)
colour=["r","g","b"]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("percentages of Female raped in 2015 and location")
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")
a=rp["%M"].iloc[3]
b=rp["%M"].iloc[7]
c=rp["%M"].iloc[11]
d=a,b,c
print(d)
plt.figure(figsize=(10,5))
plt.subplot(122)
myexplode=[0,0.05,0]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("percentages of Male raped in 2015 and location",)
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")
# Out:
# (67.53, 53.83, 62.53)
# (32.47, 46.17, 37.47)

# %%
a=rp["%F"].iloc[16]
b=rp["%F"].iloc[20]
c=rp["%F"].iloc[24]
d=a,b,c
print(d)
myexplode=[0.05,0,0]
plt.figure(figsize=(10,5))
plt.subplot(121)
colour=["b","g","y"]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("percentages of Female raped in 2016 and location")
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")
a=rp["%M"].iloc[16]
b=rp["%M"].iloc[20]
c=rp["%M"].iloc[24]
d=a,b,c
print(d)
plt.figure(figsize=(10,5))
plt.subplot(122)
myexplode=[0,0.05,0]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("percentages of Male raped in 2016 and location",)
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")
# Out:
# (76.73, 56.85, 73.03)
# (23.27, 43.15, 26.97)

# %%
a=rp["%F"].iloc[29]
b=rp["%F"].iloc[33]
c=rp["%F"].iloc[37]
d=a,b,c
print(d)
myexplode=[0,0.05,0]
plt.figure(figsize=(10,5))
plt.subplot(121)
colour=["b","m","c"]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("Percentages Of Female Raped In 2017 And Location")
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")

a=rp["%M"].iloc[29]
b=rp["%M"].iloc[33]
c=rp["%M"].iloc[37]
d=a,b,c
print(d)
plt.figure(figsize=(10,5))
plt.subplot(122)
myexplode=[0,0,0.05]
plt.pie(d,labels=["HOME","SCHOOL","OTHERS"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("Percentages Of Male Raped In 2017 And Location",)
plt.startangle=90
plt.legend(title="Place of Rape",loc="lower left")
# Out:
# (69.33, 93.37, 54.55)
# (30.67, 6.63, 45.45)

# %%
a=rp["Total"].iloc[12]
b=rp["Total"].iloc[25]
c=rp["Total"].iloc[38]
d=a,b,c
print(d)
myexplode=[0,0,0]
plt.figure(figsize=(10,5))
plt.subplot(121)
colour=["c","b","y"]
plt.pie(d,labels=["2015","2016","2017"],colors=colour,autopct="%.1f%%",explode=myexplode,shadow=True)
plt.title("Percentages Of National Rape Incidence From 2015 - 2017")
plt.startangle=90
plt.legend(title="Years",loc="lower left")
# Out:
# (2143, 2404, 1053)
