# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
af=pd.read_csv("afghan.csv")
print(af)
# Out:
#     COUNTRY_OF_ASYLUM                   RETURN_DATE         ORIG_PROV_NAME  \
# 0            #country                #date+occurred  #admin1+name+x_origin
# 1                Iran       Sunday, January 3, 2021                  Herat
# 2                Iran      Tuesday, January 5, 2021                 Bamyan
# 3                Iran      Tuesday, January 5, 2021                 Ghazni
# 4                Iran      Tuesday, January 5, 2021                 Ghazni
# ..                ...                           ...                    ...
# 674              Iran      Monday, November 8, 2021                  Farah
# 675              Iran      Monday, November 8, 2021                 Ghazni
# 676              Iran      Monday, November 8, 2021                  Kabul
# 677              Iran  Wednesday, November 10, 2021                 Kunduz
# 678               NaN                           NaN                    NaN
#
#             ORIG_DIST_NAME       DESTINATION_PROV_NAME  \
# ...

# %%
af.isnull()
# Out:
#      COUNTRY_OF_ASYLUM  RETURN_DATE  ORIG_PROV_NAME  ORIG_DIST_NAME  \
# 0                False        False           False           False
# 1                False        False           False           False
# 2                False        False           False           False
# 3                False        False           False           False
# 4                False        False           False           False
# ..                 ...          ...             ...             ...
# 674              False        False           False           False
# 675              False        False           False           False
# 676              False        False           False           False
# 677              False        False           False           False
# 678               True         True            True            True
#
#      DESTINATION_PROV_NAME  DESTINATION_DIST_NAME  INDIVIDUALS   MALE  FEMALE
# ...

# %%
af.fillna(0)
# Out:
#     COUNTRY_OF_ASYLUM                   RETURN_DATE         ORIG_PROV_NAME  \
# 0            #country                #date+occurred  #admin1+name+x_origin
# 1                Iran       Sunday, January 3, 2021                  Herat
# 2                Iran      Tuesday, January 5, 2021                 Bamyan
# 3                Iran      Tuesday, January 5, 2021                 Ghazni
# 4                Iran      Tuesday, January 5, 2021                 Ghazni
# ..                ...                           ...                    ...
# 674              Iran      Monday, November 8, 2021                  Farah
# 675              Iran      Monday, November 8, 2021                 Ghazni
# 676              Iran      Monday, November 8, 2021                  Kabul
# 677              Iran  Wednesday, November 10, 2021                 Kunduz
# 678                 0                             0                      0
#
#             ORIG_DIST_NAME       DESTINATION_PROV_NAME  \
# ...

# %%
af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   COUNTRY_OF_ASYLUM      678 non-null    object
#  1   RETURN_DATE            678 non-null    object
#  2   ORIG_PROV_NAME         678 non-null    object
#  3   ORIG_DIST_NAME         678 non-null    object
#  4   DESTINATION_PROV_NAME  678 non-null    object
#  5   DESTINATION_DIST_NAME  678 non-null    object
#  6   INDIVIDUALS            678 non-null    object
#  7   MALE                   678 non-null    object
#  8   FEMALE                 678 non-null    object
# dtypes: object(9)
# memory usage: 47.9+ KB

# %%
af.sort_values(by=["RETURN_DATE"])
# Out:
#     COUNTRY_OF_ASYLUM                    RETURN_DATE         ORIG_PROV_NAME  \
# 0            #country                 #date+occurred  #admin1+name+x_origin
# 391              Iran         Friday, April 16, 2021                 Parwan
# 368              Iran          Friday, April 9, 2021               Daykundi
# 367              Iran          Friday, April 9, 2021                 Bamyan
# 366              Iran          Friday, April 9, 2021                 Bamyan
# ..                ...                            ...                    ...
# 647              Iran  Wednesday, September 15, 2021               Samangan
# 654              Iran  Wednesday, September 22, 2021              Sar-e-Pul
# 653              Iran  Wednesday, September 22, 2021                  Balkh
# 659     Other Country  Wednesday, September 29, 2021                  Balkh
# 678               NaN                            NaN                    NaN
#
# ...

# %%
data1=af.DESTINATION_DIST_NAME.iloc[1:20]
data2=af.INDIVIDUALS.iloc[1:20]
plt.figure(figsize=(20,5))
plt.bar(data1,data2,width=0.3)
plt.xlabel("Return Date")
plt.ylabel("Individuals")
plt.title("graph")
plt.show()

# %%
plt.pie(data2,labels=data1)
plt.legend(loc="lower center",ncol=10)

# %%
id=pd.read_csv("indicators.csv")
print(id)
# Out:
#         Country Name   Country ISO3        Year  \
# 0      #country+name  #country+code  #date+year
# 1            Nigeria            NGA        2007
# 2            Nigeria            NGA        2006
# 3            Nigeria            NGA        2005
# 4            Nigeria            NGA        2004
# ...              ...            ...         ...
# 72146        Nigeria            NGA        1981
# 72147        Nigeria            NGA        1980
# 72148        Nigeria            NGA        1979
# 72149        Nigeria            NGA        1978
# 72150        Nigeria            NGA        1977
#
#                                           Indicator Name     Indicator Code  \
# 0                                        #indicator+name    #indicator+code
# 1                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 2                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 3                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# ...
