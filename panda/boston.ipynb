# %%
import numpy as np
import pandas as pd

# %%
#Assigning values

# %%
#dataframe
Ng = pd.DataFrame(
    {"States":["Edo","Akwa","Abuja","Lagos","Ondo","Kano"],
          "Population":[120000000,75000000,2000000,150000000,5000000,200000000],
          "Budget":[25000000,30000000,40000000,100000000,10000000,150000000],
          "Revenue":[10000000,15000000,5000000,200000000,3000000,1500000000],
          "Expdenditure":[3000000,7000000,2500000,100000000,2000000,100000000],
          "Remarks":["GOOD","VERY GOOD","FAIR","EXCELLENT","FAIR","GOOD"]
},index=["A","B","C","D","E","F"])
print(Ng)
# Out:
#   States  Population     Budget     Revenue  Expdenditure    Remarks
# A    Edo   120000000   25000000    10000000       3000000       GOOD
# B   Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C  Abuja     2000000   40000000     5000000       2500000       FAIR
# D  Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E   Ondo     5000000   10000000     3000000       2000000       FAIR
# F   Kano   200000000  150000000  1500000000     100000000       GOOD

# %%
Ng.index.name ="ID"
print(Ng)
# Out:
#    States  Population     Budget     Revenue  Expdenditure    Remarks
# ID
# A     Edo   120000000   25000000    10000000       3000000       GOOD
# B    Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C   Abuja     2000000   40000000     5000000       2500000       FAIR
# D   Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E    Ondo     5000000   10000000     3000000       2000000       FAIR
# F    Kano   200000000  150000000  1500000000     100000000       GOOD

# %%
Ng.columns.name = "item"
print(Ng)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks
# ID
# A       Edo   120000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# F      Kano   200000000  150000000  1500000000     100000000       GOOD

# %%
#creating a new column
Ng["health"] = 1250
print(Ng)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# A       Edo   120000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
#
# item  health
# ID
# A       1250
# B       1250
# C       1250
# D       1250
# E       1250
# F       1250

# %%
#creating diff.val
Ng["Health"] = [1250,300,500,540,200,400]
print(Ng)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# A       Edo   120000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
#
# item  health  Health
# ID
# A       1250    1250
# B       1250     300
# C       1250     500
# D       1250     540
# E       1250     200
# F       1250     400

# %%
#using np.arange().
ser = pd.Series(np.arange(6),index= ["red","yellow","green","black","white","pink"])

print(ser)
ser.idxmax()
# Out:
# red       0
# yellow    1
# green     2
# black     3
# white     4
# pink      5
# dtype: int32
# 'pink'

# %%
#updating a single values
Ng["Population"][0]=150000000
print(Ng)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# A       Edo   150000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
#
# item  health  Health
# ID
# A       1250    1250
# B       1250     300
# C       1250     500
# D       1250     540
# E       1250     200
# F       1250     400
# <ipython-input-9-9ef129fbb98e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ng["Population"][0]=150000000

# %%
#deleting a column
del Ng["Health"]
print(Ng)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# A       Edo   150000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
#
# item  health
# ID
# A       1250
# B       1250
# C       1250
# D       1250
# E       1250
# F       1250

# %%
#Transpose
Ng.T
# Out:
# ID                    A          B         C          D         E           F
# item
# States              Edo       Akwa     Abuja      Lagos      Ondo        Kano
# Population    150000000   75000000   2000000  150000000   5000000   200000000
# Budget         25000000   30000000  40000000  100000000  10000000   150000000
# Revenue        10000000   15000000   5000000  200000000   3000000  1500000000
# Expdenditure    3000000    7000000   2500000  100000000   2000000   100000000
# Remarks            GOOD  VERY GOOD      FAIR  EXCELLENT      FAIR        GOOD
# health             1250       1250      1250       1250      1250        1250

# %%
#idxmax()/idxmin()
Ng["Population"].idxmax()
# Out:
# 'F'

# %%
Ng["Population"].idxmin()
# Out:
# 'C'

# %%
#dropping a row for series
Ng["Revenue"].drop("F")
# Out:
# ID
# A     10000000
# B     15000000
# C      5000000
# D    200000000
# E      3000000
# Name: Revenue, dtype: int64

# %%
#dropping a row for the whole dataframe
Ng.drop("F")
# Out:
# item States  Population     Budget    Revenue  Expdenditure    Remarks  health
# ID
# A       Edo   150000000   25000000   10000000       3000000       GOOD    1250
# B      Akwa    75000000   30000000   15000000       7000000  VERY GOOD    1250
# C     Abuja     2000000   40000000    5000000       2500000       FAIR    1250
# D     Lagos   150000000  100000000  200000000     100000000  EXCELLENT    1250
# E      Ondo     5000000   10000000    3000000       2000000       FAIR    1250

# %%
#dropping column in axis
Ng.drop(["States","Remarks"],axis=1)
# Out:
# item  Population     Budget     Revenue  Expdenditure  health
# ID
# A      150000000   25000000    10000000       3000000    1250
# B       75000000   30000000    15000000       7000000    1250
# C        2000000   40000000     5000000       2500000    1250
# D      150000000  100000000   200000000     100000000    1250
# E        5000000   10000000     3000000       2000000    1250
# F      200000000  150000000  1500000000     100000000    1250

# %%
boston= pd.read_csv("C:/Users/User/Desktop/Boston.csv")
print(boston)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston["indus"].idxmax()
# Out:
# 488

# %%
boston.T
# Out:
#                   0          1          2          3          4          5    \
# Unnamed: 0    1.00000    2.00000    3.00000    4.00000    5.00000    6.00000
# crim          0.00632    0.02731    0.02729    0.03237    0.06905    0.02985
# zn           18.00000    0.00000    0.00000    0.00000    0.00000    0.00000
# indus         2.31000    7.07000    7.07000    2.18000    2.18000    2.18000
# chas          0.00000    0.00000    0.00000    0.00000    0.00000    0.00000
# nox           0.53800    0.46900    0.46900    0.45800    0.45800    0.45800
# rm            6.57500    6.42100    7.18500    6.99800    7.14700    6.43000
# age          65.20000   78.90000   61.10000   45.80000   54.20000   58.70000
# dis           4.09000    4.96710    4.96710    6.06220    6.06220    6.06220
# rad           1.00000    2.00000    2.00000    3.00000    3.00000    3.00000
# tax         296.00000  242.00000  242.00000  222.00000  222.00000  222.00000
# ...

# %%
boston.iloc[1,3]=4.08
print(boston)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   4.08     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.max()
# Out:
# Unnamed: 0    506.0000
# crim           88.9762
# zn            100.0000
# indus          27.7400
# chas            1.0000
# nox             0.8710
# rm              8.7800
# age           100.0000
# dis            12.1265
# rad            24.0000
# tax           711.0000
# ptratio        22.0000
# black         396.9000
# lstat          37.9700
# medv           50.0000
# dtype: float64

# %%
boston.drop(["rad","zn"],axis = 1)
# Out:
#      Unnamed: 0     crim  indus  chas    nox     rm   age     dis  tax  \
# 0             1  0.00632   2.31     0  0.538  6.575  65.2  4.0900  296
# 1             2  0.02731   4.08     0  0.469  6.421  78.9  4.9671  242
# 2             3  0.02729   7.07     0  0.469  7.185  61.1  4.9671  242
# 3             4  0.03237   2.18     0  0.458  6.998  45.8  6.0622  222
# 4             5  0.06905   2.18     0  0.458  7.147  54.2  6.0622  222
# ..          ...      ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263  11.93     0  0.573  6.593  69.1  2.4786  273
# 502         503  0.04527  11.93     0  0.573  6.120  76.7  2.2875  273
# 503         504  0.06076  11.93     0  0.573  6.976  91.0  2.1675  273
# 504         505  0.10959  11.93     0  0.573  6.794  89.3  2.3889  273
# 505         506  0.04741  11.93     0  0.573  6.030  80.8  2.5050  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
boston.drop([505])
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   4.08     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 500         501  0.22438   0.0   9.69     0  0.585  6.027  79.7  2.4982    6
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.index.name ="S/N"
boston.columns.name="Headers"
boston["crim"].name="Criminals"
print(boston)
# Out:
# Headers  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1                 2  0.02731   0.0   4.08     0  0.469  6.421  78.9  4.9671
# 2                 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671
# 3                 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622
# 4                 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622
# ..              ...      ...   ...    ...   ...    ...    ...   ...     ...
# 501             502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786
# 502             503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875
# 503             504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675
# 504             505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889
# 505             506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050
#
# Headers  rad  tax  ptratio   black  lstat  medv
# ...

# %%
boston.head().sort_values(by=["tax"],ascending=False)
# Out:
# Headers  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1                 2  0.02731   0.0   4.08     0  0.469  6.421  78.9  4.9671
# 2                 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671
# 3                 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622
# 4                 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622
#
# Headers  rad  tax  ptratio   black  lstat  medv
# S/N
# 0          1  296     15.3  396.90   4.98  24.0
# 1          2  242     17.8  396.90   9.14  21.6
# 2          2  242     17.8  392.83   4.03  34.7
# 3          3  222     18.7  394.63   2.94  33.4
# 4          3  222     18.7  396.90   5.33  36.2

# %%
boston.cumprod()
# Out:
# Headers  Unnamed: 0           crim          zn       indus  chas  \
# S/N
# 0                 1   6.320000e-03    2.310000    2.310000     0
# 1                 2   1.725992e-04    9.424800    9.424800     0
# 2                 6   4.710232e-06   66.633336   66.633336     0
# 3                24   1.524702e-07  145.260672  145.260672     0
# 4               120   1.052807e-08  316.668266  316.668266     0
# ..              ...            ...         ...         ...   ...
# 501               0  2.196417e-167         inf         inf     0
# 502               0  9.943179e-169         inf         inf     0
# 503               0  6.041476e-170         inf         inf     0
# 504               0  6.620853e-171         inf         inf     0
# 505               0  3.138946e-172         inf         inf     0
#
# Headers            nox            rm          age            dis  rad  \
# S/N
# 0         5.380000e-01  6.575000e+00         66.0   4.090000e+00    1
# ...

# %%
import math
np.ceil(boston.age)
# Out:
# S/N
# 0      66.0
# 1      79.0
# 2      62.0
# 3      46.0
# 4      55.0
#        ...
# 501    70.0
# 502    77.0
# 503    91.0
# 504    90.0
# 505    81.0
# Name: age, Length: 506, dtype: float64

# %%
boston.age=np.ceil(boston.age)
print(boston)
# Out:
# Headers  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632  18.0   2.31     0  0.538  6.575  66.0  4.0900
# 1                 2  0.02731   0.0   4.08     0  0.469  6.421  79.0  4.9671
# 2                 3  0.02729   0.0   7.07     0  0.469  7.185  62.0  4.9671
# 3                 4  0.03237   0.0   2.18     0  0.458  6.998  46.0  6.0622
# 4                 5  0.06905   0.0   2.18     0  0.458  7.147  55.0  6.0622
# ..              ...      ...   ...    ...   ...    ...    ...   ...     ...
# 501             502  0.06263   0.0  11.93     0  0.573  6.593  70.0  2.4786
# 502             503  0.04527   0.0  11.93     0  0.573  6.120  77.0  2.2875
# 503             504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675
# 504             505  0.10959   0.0  11.93     0  0.573  6.794  90.0  2.3889
# 505             506  0.04741   0.0  11.93     0  0.573  6.030  81.0  2.5050
#
# Headers  rad  tax  ptratio   black  lstat  medv
# ...

# %%
boston.zn=boston.indus
print(boston)
# Out:
# Headers  Unnamed: 0     crim     zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632   2.31   2.31     0  0.538  6.575  66.0  4.0900
# 1                 2  0.02731   4.08   4.08     0  0.469  6.421  79.0  4.9671
# 2                 3  0.02729   7.07   7.07     0  0.469  7.185  62.0  4.9671
# 3                 4  0.03237   2.18   2.18     0  0.458  6.998  46.0  6.0622
# 4                 5  0.06905   2.18   2.18     0  0.458  7.147  55.0  6.0622
# ..              ...      ...    ...    ...   ...    ...    ...   ...     ...
# 501             502  0.06263  11.93  11.93     0  0.573  6.593  70.0  2.4786
# 502             503  0.04527  11.93  11.93     0  0.573  6.120  77.0  2.2875
# 503             504  0.06076  11.93  11.93     0  0.573  6.976  91.0  2.1675
# 504             505  0.10959  11.93  11.93     0  0.573  6.794  90.0  2.3889
# 505             506  0.04741  11.93  11.93     0  0.573  6.030  81.0  2.5050
#
# ...

# %%
np.floor(boston.dis)
# Out:
# S/N
# 0      4.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 501    2.0
# 502    2.0
# 503    2.0
# 504    2.0
# 505    2.0
# Name: dis, Length: 506, dtype: float64

# %%
boston.head().sort_values(by=["tax","age"],ascending=True)
# Out:
# Headers  Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  \
# S/N
# 3                 4  0.03237  2.18   2.18     0  0.458  6.998  46.0  6.0622
# 4                 5  0.06905  2.18   2.18     0  0.458  7.147  55.0  6.0622
# 2                 3  0.02729  7.07   7.07     0  0.469  7.185  62.0  4.9671
# 1                 2  0.02731  4.08   4.08     0  0.469  6.421  79.0  4.9671
# 0                 1  0.00632  2.31   2.31     0  0.538  6.575  66.0  4.0900
#
# Headers  rad  tax  ptratio   black  lstat  medv
# S/N
# 3          3  222     18.7  394.63   2.94  33.4
# 4          3  222     18.7  396.90   5.33  36.2
# 2          2  242     17.8  392.83   4.03  34.7
# 1          2  242     17.8  396.90   9.14  21.6
# 0          1  296     15.3  396.90   4.98  24.0

# %%
#renaming columns
boston = pd.DataFrame(boston)
print(boston)
# Out:
# Headers  Unnamed: 0     crim     zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632   2.31   2.31     0  0.538  6.575  66.0  4.0900
# 1                 2  0.02731   4.08   4.08     0  0.469  6.421  79.0  4.9671
# 2                 3  0.02729   7.07   7.07     0  0.469  7.185  62.0  4.9671
# 3                 4  0.03237   2.18   2.18     0  0.458  6.998  46.0  6.0622
# 4                 5  0.06905   2.18   2.18     0  0.458  7.147  55.0  6.0622
# ..              ...      ...    ...    ...   ...    ...    ...   ...     ...
# 501             502  0.06263  11.93  11.93     0  0.573  6.593  70.0  2.4786
# 502             503  0.04527  11.93  11.93     0  0.573  6.120  77.0  2.2875
# 503             504  0.06076  11.93  11.93     0  0.573  6.976  91.0  2.1675
# 504             505  0.10959  11.93  11.93     0  0.573  6.794  90.0  2.3889
# 505             506  0.04741  11.93  11.93     0  0.573  6.030  81.0  2.5050
#
# ...

# %%
boston.rename(columns={"crim":"criminals","zn":"zero No"})
# Out:
# Headers  Unnamed: 0  criminals  zero No  indus  chas    nox     rm   age  \
# S/N
# 0                 1    0.00632     2.31   2.31     0  0.538  6.575  66.0
# 1                 2    0.02731     4.08   4.08     0  0.469  6.421  79.0
# 2                 3    0.02729     7.07   7.07     0  0.469  7.185  62.0
# 3                 4    0.03237     2.18   2.18     0  0.458  6.998  46.0
# 4                 5    0.06905     2.18   2.18     0  0.458  7.147  55.0
# ..              ...        ...      ...    ...   ...    ...    ...   ...
# 501             502    0.06263    11.93  11.93     0  0.573  6.593  70.0
# 502             503    0.04527    11.93  11.93     0  0.573  6.120  77.0
# 503             504    0.06076    11.93  11.93     0  0.573  6.976  91.0
# 504             505    0.10959    11.93  11.93     0  0.573  6.794  90.0
# 505             506    0.04741    11.93  11.93     0  0.573  6.030  81.0
#
# Headers     dis  rad  tax  ptratio   black  lstat  medv
# S/N
# ...

# %%
boston.loc[505]
print(boston)
# Out:
# Headers  Unnamed: 0     crim     zn  indus  chas    nox     rm   age     dis  \
# S/N
# 0                 1  0.00632   2.31   2.31     0  0.538  6.575  66.0  4.0900
# 1                 2  0.02731   4.08   4.08     0  0.469  6.421  79.0  4.9671
# 2                 3  0.02729   7.07   7.07     0  0.469  7.185  62.0  4.9671
# 3                 4  0.03237   2.18   2.18     0  0.458  6.998  46.0  6.0622
# 4                 5  0.06905   2.18   2.18     0  0.458  7.147  55.0  6.0622
# ..              ...      ...    ...    ...   ...    ...    ...   ...     ...
# 501             502  0.06263  11.93  11.93     0  0.573  6.593  70.0  2.4786
# 502             503  0.04527  11.93  11.93     0  0.573  6.120  77.0  2.2875
# 503             504  0.06076  11.93  11.93     0  0.573  6.976  91.0  2.1675
# 504             505  0.10959  11.93  11.93     0  0.573  6.794  90.0  2.3889
# 505             506  0.04741  11.93  11.93     0  0.573  6.030  81.0  2.5050
#
# ...

# %%
boston[["rad","tax"]]
# Out:
# Headers  rad  tax
# S/N
# 0          1  296
# 1          2  242
# 2          2  242
# 3          3  222
# 4          3  222
# ..       ...  ...
# 501        1  273
# 502        1  273
# 503        1  273
# 504        1  273
# 505        1  273
#
# [506 rows x 2 columns]

# %%
boston.age== 50
# Out:
# S/N
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: age, Length: 506, dtype: bool

# %%
#sorting values

# %%
Ng.sort_index(ascending= False)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# A       Edo   150000000   25000000    10000000       3000000       GOOD
#
# item  health
# ID
# F       1250
# E       1250
# D       1250
# C       1250
# B       1250
# A       1250

# %%
#sorting labels
Ng.sort_index(axis=1)
# Out:
# item     Budget  Expdenditure  Population    Remarks     Revenue States  \
# ID
# A      25000000       3000000   150000000       GOOD    10000000    Edo
# B      30000000       7000000    75000000  VERY GOOD    15000000   Akwa
# C      40000000       2500000     2000000       FAIR     5000000  Abuja
# D     100000000     100000000   150000000  EXCELLENT   200000000  Lagos
# E      10000000       2000000     5000000       FAIR     3000000   Ondo
# F     150000000     100000000   200000000       GOOD  1500000000   Kano
#
# item  health
# ID
# A       1250
# B       1250
# C       1250
# D       1250
# E       1250
# F       1250

# %%
#sorting by actual values
Ng.sort_values(by = "Population")
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# A       Edo   150000000   25000000    10000000       3000000       GOOD
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
#
# item  health
# ID
# C       1250
# E       1250
# B       1250
# A       1250
# D       1250
# F       1250

# %%
Ng.sort_values(by=["Population","Budget"],ascending=False)
# Out:
# item States  Population     Budget     Revenue  Expdenditure    Remarks  \
# ID
# F      Kano   200000000  150000000  1500000000     100000000       GOOD
# D     Lagos   150000000  100000000   200000000     100000000  EXCELLENT
# A       Edo   150000000   25000000    10000000       3000000       GOOD
# B      Akwa    75000000   30000000    15000000       7000000  VERY GOOD
# E      Ondo     5000000   10000000     3000000       2000000       FAIR
# C     Abuja     2000000   40000000     5000000       2500000       FAIR
#
# item  health
# ID
# F       1250
# D       1250
# A       1250
# B       1250
# E       1250
# C       1250

# %%
#ceil/floor
np.floor(boston.age)
# Out:
# S/N
# 0      66.0
# 1      79.0
# 2      62.0
# 3      46.0
# 4      55.0
#        ...
# 501    70.0
# 502    77.0
# 503    91.0
# 504    90.0
# 505    81.0
# Name: age, Length: 506, dtype: float64

# %%
boston.age.median()
# Out:
# 78.0

# %%
boston.age.mean()
# Out:
# 68.97826086956522

# %%
boston.age.mode()
# Out:
# 0    100.0
# dtype: float64
